# %% [markdown]
# <a href="https://colab.research.google.com/github/SANAD343/Salary_DataSet_Pandas_EDA/blob/main/Salary_DataSet_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA (Exploratory Data Analysis)
#   # Steps for EDA
# *  Step1: Load the data set
# *  Step2: Read the external Data
# *  Step3: Basic Pandas and Numpy and Prepare the Data.
# *  Step4: Cleaning the data(missing value handling)
# *  Step5: Finding the pattern and then the value

# %%
import pandas as pd
import numpy as np

# %%
# Pandas Version

print(pd.__version__)
# Out:
# 2.0.3

# %%
df=pd.read_csv("/content/sample_data/Salaries_DataSet.csv")

# %%
df.head()
# Out:
#    rank discipline   phd  service   sex    salary
# 0  Prof          B  56.0       49  Male  186960.0
# 1  Prof          A  12.0        6  Male   93000.0
# 2  Prof          A  23.0       20  Male  110515.0
# 3  Prof          A  40.0       31  Male  131205.0
# 4  Prof          B  20.0       18  Male  104800.0

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (78, 6)

# %%
df.size
# Out:
# 468

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# rank           object
# discipline     object
# phd           float64
# service         int64
# sex            object
# salary        float64
# dtype: object

# %%
df.describe()
# Out:
#              phd    service         salary
# count  76.000000  78.000000      76.000000
# mean   19.605263  15.051282  108003.355263
# std    12.508215  12.139768   28525.350088
# min     1.000000   0.000000   57800.000000
# 25%    10.000000   5.250000   87250.000000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.250000  20.750000  127077.750000
# max    56.000000  51.000000  186960.000000

# %%
type(df.shape)
# Out:
# tuple

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.tail()
# Out:
#          rank discipline   phd  service     sex    salary
# 73       Prof          B  18.0       10  Female  105450.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 75       Prof          B  17.0       17  Female  124312.0
# 76       Prof          A  28.0       14  Female  109954.0
# 77       Prof          A  23.0       15  Female  109646.0

# %%
df.tail()
# Out:
#          rank discipline   phd  service     sex    salary
# 73       Prof          B  18.0       10  Female  105450.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 75       Prof          B  17.0       17  Female  124312.0
# 76       Prof          A  28.0       14  Female  109954.0
# 77       Prof          A  23.0       15  Female  109646.0

# %%
df.sample() #pull random data from the dataset
# Out:
#         rank discipline  phd  service   sex   salary
# 22  AsstProf          A  4.0        2  Male  73000.0

# %%
df.sample(5)
# Out:
#         rank discipline   phd  service     sex    salary
# 58      Prof          B  36.0       26  Female  144651.0
# 53  AsstProf          A   5.0        3  Female   73500.0
# 20  AsstProf          B   4.0        4    Male   92000.0
# 38  AsstProf          B   4.0        3    Male   91000.0
# 19      Prof          A  29.0       27    Male  150500.0

# %%
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
# ...

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=78, step=1),
#  Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')]

# %%
df["phd"]
# Out:
# 0     56.0
# 1     12.0
# 2     23.0
# 3     40.0
# 4     20.0
#       ...
# 73    18.0
# 74    19.0
# 75    17.0
# 76    28.0
# 77    23.0
# Name: phd, Length: 78, dtype: float64

# %%
df["rank"]
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df[["rank","salary"]]
# Out:
#          rank    salary
# 0        Prof  186960.0
# 1        Prof   93000.0
# 2        Prof  110515.0
# 3        Prof  131205.0
# 4        Prof  104800.0
# ..        ...       ...
# 73       Prof  105450.0
# 74  AssocProf  104542.0
# 75       Prof  124312.0
# 76       Prof  109954.0
# 77       Prof  109646.0
#
# [78 rows x 2 columns]

# %%
df["rank"].values
# Out:
# array(['Prof', 'Prof', 'Prof', 'Prof', 'Prof', 'Prof', 'AssocProf',
#        'Prof', 'Prof', 'Prof', 'Prof', 'Prof', 'AsstProf', 'Prof', 'Prof',
#        'Prof', 'AsstProf', 'AsstProf', 'Prof', 'Prof', 'AsstProf', 'Prof',
#        'AsstProf', 'AsstProf', 'Prof', 'Prof', 'Prof', 'Prof', 'AsstProf',
#        'Prof', 'AssocProf', 'Prof', 'Prof', 'Prof', 'AssocProf', 'Prof',
#        'Prof', 'Prof', 'AsstProf', 'Prof', 'Prof', 'AssocProf',
#        'AsstProf', 'AsstProf', 'Prof', 'Prof', 'AsstProf', 'AssocProf',
#        'Prof', 'Prof', 'AsstProf', 'Prof', 'Prof', 'AsstProf',
#        'AssocProf', 'AsstProf', 'AssocProf', 'AsstProf', 'Prof',
#        'AssocProf', 'AsstProf', 'AssocProf', 'AssocProf', 'Prof',
#        'AssocProf', 'Prof', 'AsstProf', 'Prof', 'AsstProf', 'Prof',
#        'AsstProf', 'AssocProf', 'Prof', 'Prof', 'AssocProf', 'Prof',
#        'Prof', 'Prof'], dtype=object)

# %%
df["salary"].values
# Out:
# array([186960.,  93000., 110515., 131205., 104800., 122400.,  81285.,
#            nan,  94350.,  57800., 128250., 134778.,  88000., 162200.,
#        153750., 150480.,  75044.,  92000., 107300., 150500.,  92000.,
#        103106.,  73000.,  85000.,  91100.,  99418., 148750., 155865.,
#            nan, 123683., 107008., 155750., 103275., 120000., 119800.,
#        126933., 146856., 102000.,  91000., 129000., 137000.,  74830.,
#         80225.,  77000., 151768., 140096.,  74692., 103613., 111512.,
#        122960.,  97032., 127512., 105000.,  73500.,  62884.,  72500.,
#         77500.,  72500., 144651., 103994.,  92000., 103750., 109650.,
#         91000.,  73300., 117555.,  63100.,  90450.,  77500., 116450.,
#         78500.,  71065., 161101., 105450., 104542., 124312., 109954.,
#        109646.])

# %%
df["rank"].unique()
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %%
df["rank"].value_counts()  #to get all data of rank
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
df[["rank","salary"]].value_counts()
# Out:
# rank       salary
# AsstProf   92000.0     3
#            72500.0     2
# AssocProf  62884.0     1
# Prof       120000.0    1
#            126933.0    1
#                       ..
# AsstProf   88000.0     1
#            85000.0     1
#            80225.0     1
#            78500.0     1
# Prof       186960.0    1
# Name: count, Length: 73, dtype: int64

# %%
df["salary"].sum()
# Out:
# 8208255.0

# %%
df["salary"].max()
# Out:
# 186960.0

# %%
df["salary"].min()
# Out:
# 57800.0

# %%
df["salary"].mean()
# Out:
# 108003.3552631579

# %%
df[["salary", "phd","service"]].mean()
# Out:
# salary     108003.355263
# phd            19.605263
# service        15.051282
# dtype: float64

# %%
#boolean Indexing we are getting the answer corresponding to every row in terms of Ture and False.

df[["salary"]]>100000
# Out:
#     salary
# 0     True
# 1    False
# 2     True
# 3     True
# 4     True
# ..     ...
# 73    True
# 74    True
# 75    True
# 76    True
# 77    True
#
# [78 rows x 1 columns]

# %%
#this technique called as Filter.

df[df["salary"]>100000]
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 4        Prof          B  20.0       18    Male  104800.0
# 5        Prof          A  20.0       20    Male  122400.0
# 10       Prof          B  39.0       33    Male  128250.0
# 11       Prof          B  23.0       23    Male  134778.0
# 13       Prof          B   NaN       33    Male  162200.0
# 14       Prof          B  25.0       19    Male  153750.0
# 15       Prof          B  17.0        3    Male  150480.0
# 18       Prof          A  19.0        7    Male  107300.0
# 19       Prof          A  29.0       27    Male  150500.0
# 21       Prof          A  33.0       30    Male  103106.0
# 26       Prof          A  38.0       19    Male  148750.0
# 27       Prof          A  45.0       43    Male  155865.0
# ...

# %%
# find all the columns within the list

print(df.columns.values)   # method 1
# Out:
# ['rank' 'discipline' 'phd' 'service' 'sex' 'salary']

# %%
# method 2

df.columns.tolist()
# Out:
# ['rank', 'discipline', 'phd', 'service', 'sex', 'salary']

# %%
print(df.head())
# Out:
#    rank discipline   phd  service   sex    salary
# 0  Prof          B  56.0       49  Male  186960.0
# 1  Prof          A  12.0        6  Male   93000.0
# 2  Prof          A  23.0       20  Male  110515.0
# 3  Prof          A  40.0       31  Male  131205.0
# 4  Prof          B  20.0       18  Male  104800.0

# %%
#getting the missing values under boolean indexing command "getting data in column"

df.isnull().any(axis=0)
# Out:
# rank          False
# discipline    False
# phd            True
# service       False
# sex           False
# salary         True
# dtype: bool

# %%
#"row wise data analysis"

df[df.isnull().any(axis=1)]
# Out:
#          rank discipline   phd  service   sex    salary
# 7        Prof          A  18.0       18  Male       NaN
# 13       Prof          B   NaN       33  Male  162200.0
# 28   AsstProf          B   7.0        2  Male       NaN
# 34  AssocProf          B   NaN        8  Male  119800.0

# %%
df.dropna()
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 1        Prof          A  12.0        6    Male   93000.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 4        Prof          B  20.0       18    Male  104800.0
# ..        ...        ...   ...      ...     ...       ...
# 73       Prof          B  18.0       10  Female  105450.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 75       Prof          B  17.0       17  Female  124312.0
# 76       Prof          A  28.0       14  Female  109954.0
# 77       Prof          A  23.0       15  Female  109646.0
#
# [74 rows x 6 columns]

# %%
#data Slicing and Grouping

df["phd"]
# Out:
# 0     56.0
# 1     12.0
# 2     23.0
# 3     40.0
# 4     20.0
#       ...
# 73    18.0
# 74    19.0
# 75    17.0
# 76    28.0
# 77    23.0
# Name: phd, Length: 78, dtype: float64

# %%
df["service"].describe()
# Out:
# count    78.000000
# mean     15.051282
# std      12.139768
# min       0.000000
# 25%       5.250000
# 50%      14.500000
# 75%      20.750000
# max      51.000000
# Name: service, dtype: float64

# %%
# use of GroupBy Command

df_rank=df.groupby("rank")
print(df_rank)

# %%
df_rank.head()
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 1        Prof          A  12.0        6    Male   93000.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 4        Prof          B  20.0       18    Male  104800.0
# 6   AssocProf          A  20.0       17    Male   81285.0
# 12   AsstProf          B   1.0        0    Male   88000.0
# 16   AsstProf          B   8.0        3    Male   75044.0
# 17   AsstProf          B   4.0        0    Male   92000.0
# 20   AsstProf          B   4.0        4    Male   92000.0
# 22   AsstProf          A   4.0        2    Male   73000.0
# 30  AssocProf          B   9.0        7    Male  107008.0
# 34  AssocProf          B   NaN        8    Male  119800.0
# 41  AssocProf          A  13.0        8  Female   74830.0
# 47  AssocProf          B  11.0       11  Female  103613.0

# %%
df_rank2= df.groupby("sex")
print(df_rank2)

# %%
df_rank2["salary"].mean()
# Out:
# sex
# Female    101002.410256
# Male      115382.729730
# Name: salary, dtype: float64

# %%
df_rank2[["salary"]].mean() #within DataFrame
# Out:
#                salary
# sex
# Female  101002.410256
# Male    115382.729730

# %%
df.groupby("rank",sort=False)[["salary"]].mean() #use of data frame
# Out:
#                   salary
# rank
# Prof       123565.355556
# AssocProf   91786.230769
# AsstProf    80810.722222

# %%
df.groupby("rank",sort=False)["phd"].mean() #without data frame
# Out:
# rank
# Prof         26.888889
# AssocProf    15.333333
# AsstProf      5.052632
# Name: phd, dtype: float64

# %%
g=df.sort_values(by='salary', ascending=False)[['salary']].mean #by clause work over all dataframe
print(g)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of       salary
# 0   186960.0
# 13  162200.0
# 72  161101.0
# 27  155865.0
# 31  155750.0
# ..       ...
# 66   63100.0
# 54   62884.0
# 9    57800.0
# 7        NaN
# 28       NaN
#
# [78 rows x 1 columns]>

# %%
df.sort_values(by='salary', ascending=False)[['salary']]
# Out:
#       salary
# 0   186960.0
# 13  162200.0
# 72  161101.0
# 27  155865.0
# 31  155750.0
# ..       ...
# 66   63100.0
# 54   62884.0
# 9    57800.0
# 7        NaN
# 28       NaN
#
# [78 rows x 1 columns]

# %%
df["salary"]>160000 #boolean Indexing
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 73    False
# 74    False
# 75    False
# 76    False
# 77    False
# Name: salary, Length: 78, dtype: bool

# %%
df[df["salary"]>160000]
# Out:
#     rank discipline   phd  service     sex    salary
# 0   Prof          B  56.0       49    Male  186960.0
# 13  Prof          B   NaN       33    Male  162200.0
# 72  Prof          B  24.0       15  Female  161101.0

# %%
#find the mean values of the salary for diciplin A

# %%
#method1 this method will not work

df_rank= df.groupby("discipline")
print(df_rank)

# %%
#groupby will not be able to work beacue it will not able to compare with other data

df.groupby("discipline",sort=False)[["salary"]].mean()
# Out:
#                    salary
# discipline
# B           116942.317073
# A            97532.000000

# %%
df[df["discipline"]=="A"]["salary"].mean() #method 2
# Out:
# 97532.0

# %%
#extract only obeseravation with more then one lack salary
#find how many male and female professor group.

df[df["salary"]>100000]
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 4        Prof          B  20.0       18    Male  104800.0
# 5        Prof          A  20.0       20    Male  122400.0
# 10       Prof          B  39.0       33    Male  128250.0
# 11       Prof          B  23.0       23    Male  134778.0
# 13       Prof          B   NaN       33    Male  162200.0
# 14       Prof          B  25.0       19    Male  153750.0
# 15       Prof          B  17.0        3    Male  150480.0
# 18       Prof          A  19.0        7    Male  107300.0
# 19       Prof          A  29.0       27    Male  150500.0
# 21       Prof          A  33.0       30    Male  103106.0
# 26       Prof          A  38.0       19    Male  148750.0
# 27       Prof          A  45.0       43    Male  155865.0
# ...

# %%
df[df["salary"]>100000].groupby("sex").count()
# Out:
#         rank  discipline  phd  service  salary
# sex
# Female    21          21   21       21      21
# Male      24          24   22       24      24

# %%
df[df["salary"]>100000].groupby("sex")[["salary"]].count()
# Out:
#         salary
# sex
# Female      21
# Male        24

# %%
df[10:20]
# Out:
#         rank discipline   phd  service   sex    salary
# 10      Prof          B  39.0       33  Male  128250.0
# 11      Prof          B  23.0       23  Male  134778.0
# 12  AsstProf          B   1.0        0  Male   88000.0
# 13      Prof          B   NaN       33  Male  162200.0
# 14      Prof          B  25.0       19  Male  153750.0
# 15      Prof          B  17.0        3  Male  150480.0
# 16  AsstProf          B   8.0        3  Male   75044.0
# 17  AsstProf          B   4.0        0  Male   92000.0
# 18      Prof          A  19.0        7  Male  107300.0
# 19      Prof          A  29.0       27  Male  150500.0

# %%
df.iloc[10:20,[0,3,4,5]] #coloumn cerain column and certain row
# Out:
#         rank  service   sex    salary
# 10      Prof       33  Male  128250.0
# 11      Prof       23  Male  134778.0
# 12  AsstProf        0  Male   88000.0
# 13      Prof       33  Male  162200.0
# 14      Prof       19  Male  153750.0
# 15      Prof        3  Male  150480.0
# 16  AsstProf        3  Male   75044.0
# 17  AsstProf        0  Male   92000.0
# 18      Prof        7  Male  107300.0
# 19      Prof       27  Male  150500.0

# %%
df[0:1]
# Out:
#    rank discipline   phd  service   sex    salary
# 0  Prof          B  56.0       49  Male  186960.0

# %%
df.iloc[0]
# Out:
# rank              Prof
# discipline           B
# phd               56.0
# service             49
# sex               Male
# salary        186960.0
# Name: 0, dtype: object

# %%
df.iloc[:,1:3]
# Out:
#    discipline   phd
# 0           B  56.0
# 1           A  12.0
# 2           A  23.0
# 3           A  40.0
# 4           B  20.0
# ..        ...   ...
# 73          B  18.0
# 74          B  19.0
# 75          B  17.0
# 76          A  28.0
# 77          A  23.0
#
# [78 rows x 2 columns]

# %%
df.iloc[1:3,0:2]
# Out:
#    rank discipline
# 1  Prof          A
# 2  Prof          A

# %%
df.loc[10:20,["rank","salary"]]
# Out:
#         rank    salary
# 10      Prof  128250.0
# 11      Prof  134778.0
# 12  AsstProf   88000.0
# 13      Prof  162200.0
# 14      Prof  153750.0
# 15      Prof  150480.0
# 16  AsstProf   75044.0
# 17  AsstProf   92000.0
# 18      Prof  107300.0
# 19      Prof  150500.0
# 20  AsstProf   92000.0

# %%
#sorting

df.sort_values("service")
# Out:
#         rank discipline   phd  service     sex    salary
# 55  AsstProf          A   2.0        0  Female   72500.0
# 23  AsstProf          A   2.0        0    Male   85000.0
# 43  AsstProf          B   5.0        0  Female   77000.0
# 17  AsstProf          B   4.0        0    Male   92000.0
# 12  AsstProf          B   1.0        0    Male   88000.0
# ..       ...        ...   ...      ...     ...       ...
# 40      Prof          A  39.0       36  Female  137000.0
# 27      Prof          A  45.0       43    Male  155865.0
# 36      Prof          B  45.0       45    Male  146856.0
# 0       Prof          B  56.0       49    Male  186960.0
# 9       Prof          A  51.0       51    Male   57800.0
#
# [78 rows x 6 columns]

# %%
df["service"].values
# Out:
# array([49,  6, 20, 31, 18, 20, 17, 18, 19, 51, 33, 23,  0, 33, 19,  3,  3,
#         0,  7, 27,  4, 30,  2,  0, 23, 31, 19, 43,  2, 20,  7, 21, 19, 18,
#         8, 23, 45,  8,  3, 18, 36,  8,  2,  0, 19, 25,  3, 11, 17, 18,  5,
#        14,  0,  3, 22,  0,  8,  1, 26, 10,  3, 10,  7, 27, 24, 19,  6, 11,
#         2,  7,  3,  9, 15, 10,  6, 17, 14, 15])

# %%
df_sorted=df.sort_values(by="service").head()
print(df_sorted)
# Out:
#         rank discipline  phd  service     sex   salary
# 55  AsstProf          A  2.0        0  Female  72500.0
# 23  AsstProf          A  2.0        0    Male  85000.0
# 43  AsstProf          B  5.0        0  Female  77000.0
# 17  AsstProf          B  4.0        0    Male  92000.0
# 12  AsstProf          B  1.0        0    Male  88000.0

# %%
df.sort_index(ascending=False) #command for sorting
# Out:
#          rank discipline   phd  service     sex    salary
# 77       Prof          A  23.0       15  Female  109646.0
# 76       Prof          A  28.0       14  Female  109954.0
# 75       Prof          B  17.0       17  Female  124312.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 73       Prof          B  18.0       10  Female  105450.0
# ..        ...        ...   ...      ...     ...       ...
# 4        Prof          B  20.0       18    Male  104800.0
# 3        Prof          A  40.0       31    Male  131205.0
# 2        Prof          A  23.0       20    Male  110515.0
# 1        Prof          A  12.0        6    Male   93000.0
# 0        Prof          B  56.0       49    Male  186960.0
#
# [78 rows x 6 columns]

# %%
df.iloc[[5,10],0:2]
# Out:
#     rank discipline
# 5   Prof          A
# 10  Prof          B

# %%
df.iloc[5:10,0:2]
# Out:
#         rank discipline
# 5       Prof          A
# 6  AssocProf          A
# 7       Prof          A
# 8       Prof          A
# 9       Prof          A

# %%
df.iloc[:,0:2]
# Out:
#          rank discipline
# 0        Prof          B
# 1        Prof          A
# 2        Prof          A
# 3        Prof          A
# 4        Prof          B
# ..        ...        ...
# 73       Prof          B
# 74  AssocProf          B
# 75       Prof          B
# 76       Prof          A
# 77       Prof          A
#
# [78 rows x 2 columns]

# %%
df.iloc[10,:] #specific row with all column.
# Out:
# rank              Prof
# discipline           B
# phd               39.0
# service             33
# sex               Male
# salary        128250.0
# Name: 10, dtype: object

# %%
#aggregate functions

# %%
df.max()
# Out:
# rank              Prof
# discipline           B
# phd               56.0
# service             51
# sex               Male
# salary        186960.0
# dtype: object

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                 1.0
# service               0
# sex              Female
# salary          57800.0
# dtype: object

# %%
#aggregate functions.

df[["salary","service"]].agg(["min","max","mean"])
# Out:
#              salary    service
# min    57800.000000   0.000000
# max   186960.000000  51.000000
# mean  108003.355263  15.051282

# %%
df.agg({"salary":["min","max","mean"],"service":"nunique"})
# Out:
#                 salary  service
# min       57800.000000      NaN
# max      186960.000000      NaN
# mean     108003.355263      NaN
# nunique            NaN     33.0
